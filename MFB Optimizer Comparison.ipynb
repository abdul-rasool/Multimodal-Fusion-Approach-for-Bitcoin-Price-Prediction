# %%
import json
import requests
from keras.models import Sequential
from keras.layers import Activation, Dense, Dropout, LSTM
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.metrics import mean_absolute_error
from tabulate import tabulate

get_ipython().run_line_magic('matplotlib', 'inline')
from IPython.display import display, HTML
# Out:
# 2024-01-27 16:03:26.116944: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-27 16:03:26.234170: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-01-27 16:03:26.831276: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-11.0/lib64
# 2024-01-27 16:03:26.831354: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-11.0/lib64
# 2024-01-27 16:03:26.831361: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
import json
import requests
from keras.utils import plot_model
from keras.models import Sequential
from keras.layers import Activation, Dense, Dropout, LSTM, Bidirectional, GRU, BatchNormalization
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.metrics import mean_absolute_error
get_ipython().run_line_magic('matplotlib', 'inline')

# %%
df1 = pd.read_csv('/home/hanping/remote file/MFB/dataset/processed/text_grouped.csv')
df2 = pd.read_csv('/home/hanping/remote file/MFB/dataset/processed/btc_grouped.csv')

# %%
df1['date'] = pd.to_datetime(df1['date'])
df1.set_index('date', inplace=True)

df2['date'] = pd.to_datetime(df2['date'])
df2.set_index('date', inplace=True)

# %%
# merge the two dataframes
df_merged = pd.merge(df1, df2, on='date', how='inner')

df_merged = df_merged.sort_values('date')
df = df_merged

target_col = 'Close'
df.head()
# Out:
#                      compound     Close  Stochastic          ADI          EMA  \
# date
# 2021-01-01 00:00:00    6.8806  28995.13   86.781857  1225550.420  28876.78754
# 2021-01-01 01:00:00   15.9848  29409.99   96.295679  1229681.093  28947.88120
# 2021-01-01 02:00:00   10.3930  29194.65   83.003086  1228327.545  28980.78371
# 2021-01-01 03:00:00    3.4254  29278.40   85.898804  1228595.460  29020.46588
# 2021-01-01 04:00:00    4.3995  29220.31   78.456428  1228685.879  29047.11176
#
#                            MACD        RSI          OBV         ATR
# date
# 2021-01-01 00:00:00  133.534560  55.394904  535353.6668  378.718086
# 2021-01-01 01:00:00  164.922849  62.207462  540756.7353  388.070365
# 2021-01-01 02:00:00  170.457230  57.314228  538372.5037  385.010339
# 2021-01-01 03:00:00  179.531664  58.675685  539833.8488  373.008172
# 2021-01-01 04:00:00  179.961357  57.310301  537795.8020  372.479017

# %%
def train_test_split(df, test_size=0.2):
    split_row = len(df) - int(test_size * len(df))
    train_data = df.iloc[:split_row]
    test_data = df.iloc[split_row:]
    return train_data, test_data

# %%
train, test = train_test_split(df2, test_size=0.2)

# %%
def normalise_zero_base(df):
    return df / df.iloc[0] - 1


def normalise_min_max(df):
    return (df - df.min()) / (df.max() - df.min())


def extract_window_data(df, window_len=5, zero_base=True):
    window_data = []
    for idx in range(len(df) - window_len):
        tmp = df[idx: (idx + window_len)].copy()
        if zero_base:
            tmp = normalise_zero_base(tmp)
        window_data.append(tmp.values)
    return np.array(window_data)

# %%
def extract_window_data(df, window_len=5, zero_base=True):
    window_data = []
    for idx in range(len(df) - window_len):
        tmp = df[idx: (idx + window_len)].copy()
        if zero_base:
            tmp = normalise_zero_base(tmp)
        window_data.append(tmp.values)
    return np.array(window_data)

# %%
def prepare_data(df, target_col, window_len=10, zero_base=True, test_size=0.2):
    train_data, test_data = train_test_split(df, test_size=test_size)
    X_train = extract_window_data(train_data, window_len, zero_base)
    X_test = extract_window_data(test_data, window_len, zero_base)
    y_train = train_data[target_col][window_len:].values
    y_test = test_data[target_col][window_len:].values
    if zero_base:
        y_train = y_train / train_data[target_col][:-window_len].values - 1
        y_test = y_test / test_data[target_col][:-window_len].values - 1

    return train_data, test_data, X_train, X_test, y_train, y_test

# %%
def build_hybrid_model(input_data, output_size, neurons=100, activ_func='linear',
                       dropout=0.2, loss='mse', optimizer='adam'):
    model = Sequential()
    model.add(
        Bidirectional(LSTM(neurons, input_shape=(input_data.shape[1], input_data.shape[2]), return_sequences=True)))
    model.add(Dropout(dropout))
    model.add(Bidirectional(GRU(neurons, return_sequences=False)))
    model.add(Dropout(0.2))

    model.add(Dense(units=output_size, activation=activ_func))

    model.compile(loss=loss, optimizer=optimizer)
    return model

# %%
np.random.seed(42)
window_len = 5
test_size = 0.2
zero_base = True
hybrid_neurons = 256
epochs = 50
batch_size = 8
loss = 'mse'
dropout = 0.2
optimizer = 'adam'

# %%
train, test, X_train, X_test, y_train, y_test = prepare_data(
    df2, target_col, window_len=window_len, zero_base=zero_base, test_size=test_size)

# %%
model = build_hybrid_model(
    X_train, output_size=1, neurons=hybrid_neurons, dropout=dropout, loss=loss,
    optimizer=optimizer)
history = model.fit(
    X_train, y_train, validation_data=(X_test, y_test), epochs=epochs, batch_size=batch_size, verbose=1, shuffle=True)
# Out:
# Epoch 1/50
# 2024-01-27 16:03:28.731528: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-11.0/lib64
# 2024-01-27 16:03:28.732281: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2024-01-27 16:03:28.732606: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 281/281 [==============================] - 12s 23ms/step - loss: 0.0263 - val_loss: 0.0041
# Epoch 2/50
# 281/281 [==============================] - 5s 19ms/step - loss: 0.0070 - val_loss: 0.0027
# Epoch 3/50
# 281/281 [==============================] - 5s 19ms/step - loss: 0.0044 - val_loss: 0.0036
# Epoch 4/50
# 281/281 [==============================] - 5s 19ms/step - loss: 0.0013 - val_loss: 4.8251e-04
# Epoch 5/50
# 281/281 [==============================] - 5s 19ms/step - loss: 0.0014 - val_loss: 2.3237e-04
# Epoch 6/50
# 281/281 [==============================] - 5s 19ms/step - loss: 8.6107e-04 - val_loss: 1.8209e-04
# Epoch 7/50
# 281/281 [==============================] - 5s 19ms/step - loss: 8.5866e-04 - val_loss: 2.4608e-04
# Epoch 8/50
# 281/281 [==============================] - 5s 19ms/step - loss: 6.8089e-04 - val_loss: 1.8835e-04
# Epoch 9/50
# 281/281 [==============================] - 5s 19ms/step - loss: 5.7317e-04 - val_loss: 2.2929e-04
# Epoch 10/50
# 281/281 [==============================] - 5s 19ms/step - loss: 0.0010 - val_loss: 2.9816e-04
# Epoch 11/50
# 281/281 [==============================] - 5s 19ms/step - loss: 4.0179e-04 - val_loss: 2.3237e-04
# Epoch 12/50
# 281/281 [==============================] - 5s 20ms/step - loss: 2.9143e-04 - val_loss: 2.2976e-04
# Epoch 13/50
# 281/281 [==============================] - 5s 19ms/step - loss: 4.0918e-04 - val_loss: 2.0204e-04
# Epoch 14/50
# 281/281 [==============================] - 5s 20ms/step - loss: 2.9741e-04 - val_loss: 2.0186e-04
# Epoch 15/50
# 281/281 [==============================] - 5s 19ms/step - loss: 3.1252e-04 - val_loss: 1.8882e-04
# Epoch 16/50
# 281/281 [==============================] - 5s 19ms/step - loss: 3.2109e-04 - val_loss: 1.8303e-04
# Epoch 17/50
# 281/281 [==============================] - 5s 19ms/step - loss: 6.8228e-04 - val_loss: 2.1161e-04
# Epoch 18/50
# 281/281 [==============================] - 5s 20ms/step - loss: 5.2965e-04 - val_loss: 1.5062e-04
# Epoch 19/50
# 281/281 [==============================] - 5s 19ms/step - loss: 2.4056e-04 - val_loss: 1.9796e-04
# Epoch 20/50
# 281/281 [==============================] - 5s 19ms/step - loss: 2.0852e-04 - val_loss: 9.8465e-05
# Epoch 21/50
# 281/281 [==============================] - 5s 19ms/step - loss: 1.9087e-04 - val_loss: 1.4762e-04
# Epoch 22/50
# 281/281 [==============================] - 6s 20ms/step - loss: 1.9979e-04 - val_loss: 9.7062e-05
# Epoch 23/50
# 281/281 [==============================] - 5s 19ms/step - loss: 1.9025e-04 - val_loss: 1.0501e-04
# Epoch 24/50
# 281/281 [==============================] - 5s 20ms/step - loss: 1.9941e-04 - val_loss: 9.4589e-05
# Epoch 25/50
# 281/281 [==============================] - 5s 20ms/step - loss: 1.7586e-04 - val_loss: 1.1901e-04
# Epoch 26/50
# 281/281 [==============================] - 5s 20ms/step - loss: 1.7600e-04 - val_loss: 1.2797e-04
# Epoch 27/50
# 281/281 [==============================] - 5s 19ms/step - loss: 1.7033e-04 - val_loss: 9.8283e-05
# Epoch 28/50
# 281/281 [==============================] - 5s 19ms/step - loss: 1.7976e-04 - val_loss: 9.3243e-05
# Epoch 29/50
# 281/281 [==============================] - 5s 20ms/step - loss: 1.7187e-04 - val_loss: 9.7109e-05
# Epoch 30/50
# 281/281 [==============================] - 5s 19ms/step - loss: 1.6952e-04 - val_loss: 8.2373e-05
# Epoch 31/50
# 281/281 [==============================] - 6s 20ms/step - loss: 1.7365e-04 - val_loss: 1.3008e-04
# Epoch 32/50
# 281/281 [==============================] - 5s 19ms/step - loss: 1.6574e-04 - val_loss: 1.3207e-04
# Epoch 33/50
# 281/281 [==============================] - 6s 20ms/step - loss: 1.7548e-04 - val_loss: 1.0099e-04
# Epoch 34/50
# 281/281 [==============================] - 5s 19ms/step - loss: 1.6048e-04 - val_loss: 1.0225e-04
# Epoch 35/50
# 281/281 [==============================] - 5s 19ms/step - loss: 1.6172e-04 - val_loss: 2.0567e-04
# Epoch 36/50
# 281/281 [==============================] - 5s 19ms/step - loss: 1.6642e-04 - val_loss: 1.7051e-04
# Epoch 37/50
# 281/281 [==============================] - 6s 20ms/step - loss: 1.7324e-04 - val_loss: 8.8974e-05
# Epoch 38/50
# 281/281 [==============================] - 6s 20ms/step - loss: 1.6759e-04 - val_loss: 1.1372e-04
# Epoch 39/50
# 281/281 [==============================] - 5s 19ms/step - loss: 1.6586e-04 - val_loss: 1.0310e-04
# Epoch 40/50
# 281/281 [==============================] - 5s 19ms/step - loss: 1.8423e-04 - val_loss: 1.6680e-04
# Epoch 41/50
# 281/281 [==============================] - 5s 19ms/step - loss: 1.7800e-04 - val_loss: 1.4231e-04
# Epoch 42/50
# 281/281 [==============================] - 5s 20ms/step - loss: 1.6893e-04 - val_loss: 1.0464e-04
# Epoch 43/50
# 281/281 [==============================] - 6s 20ms/step - loss: 1.9006e-04 - val_loss: 9.4097e-05
# Epoch 44/50
# 281/281 [==============================] - 5s 19ms/step - loss: 1.6559e-04 - val_loss: 9.0326e-05
# Epoch 45/50
# 281/281 [==============================] - 5s 20ms/step - loss: 1.6538e-04 - val_loss: 1.0104e-04
# Epoch 46/50
# 281/281 [==============================] - 5s 19ms/step - loss: 1.6295e-04 - val_loss: 1.0773e-04
# Epoch 47/50
# 281/281 [==============================] - 5s 19ms/step - loss: 1.8060e-04 - val_loss: 1.1450e-04
# Epoch 48/50
# 281/281 [==============================] - 5s 19ms/step - loss: 1.8380e-04 - val_loss: 1.2636e-04
# Epoch 49/50
# 281/281 [==============================] - 5s 19ms/step - loss: 1.7000e-04 - val_loss: 1.4967e-04
# Epoch 50/50
# 281/281 [==============================] - 5s 20ms/step - loss: 1.6326e-04 - val_loss: 1.4976e-04

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'],'r',linewidth=2, label='Training loss')
plt.plot(history.history['val_loss'], 'g',linewidth=2, label='Validation loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.legend(('Training Loss', 'Validation Loss'))
plt.show()

# %%
targets = test[target_col][window_len:]
preds = model.predict(X_test).squeeze()
mean_absolute_error(y_test, preds)
# Out:
# 18/18 [==============================] - 1s 9ms/step
# 0.00856894704027708

# %%
from sklearn.metrics import mean_squared_error

MSE = mean_squared_error(preds, y_test)
MSE
# Out:
# 0.00014976027734065267

# %%
#RMSE
import math

rmse = math.sqrt(MSE)
rmse
# Out:
# 0.012237658164070962

# %%
from sklearn.metrics import r2_score

R2 = r2_score(y_test, preds)
R2
# Out:
# 0.5262452618751607

# %%
from sklearn.metrics import mean_absolute_percentage_error

mean_absolute_percentage_error(y_test, preds)
# Out:
# 5.0518337474863735

# %%
def line_plot(line1, line2, label1=None, label2=None, title='', lw=2):
    fig, ax = plt.subplots(1, figsize=(12, 5))
    ax.plot(line1, label=label1, linewidth=lw)
    ax.plot(line2, label=label2, linewidth=lw)
    ax.set_ylabel('price [BTC]', fontsize=20)
    ax.set_xlabel('Time', fontsize=20)
    ax.tick_params(labelsize=11)
    ax.set_title(title, fontsize=16)
    ax.legend(loc='best', fontsize=14);

# %%
preds = test[target_col].values[:-window_len] * (preds + 1)
preds = pd.Series(index=targets.index, data=preds)
line_plot(targets, preds, 'Actual Bitcoin Prices', 'Predicted Bitcoin Prices', lw=2)

# %%
o1_preds=preds

# %%
optimizer = 'adadelta'

# %%
model = build_hybrid_model(
    X_train, output_size=1, neurons=hybrid_neurons, dropout=dropout, loss=loss,
    optimizer=optimizer)
history = model.fit(
    X_train, y_train, validation_data=(X_test, y_test), epochs=epochs, batch_size=batch_size, verbose=1, shuffle=True)
# Out:
# Epoch 1/50
# 281/281 [==============================] - 14s 26ms/step - loss: 0.0069 - val_loss: 0.0048
# Epoch 2/50
# 281/281 [==============================] - 6s 21ms/step - loss: 0.0065 - val_loss: 0.0039
# Epoch 3/50
# 281/281 [==============================] - 6s 21ms/step - loss: 0.0063 - val_loss: 0.0031
# Epoch 4/50
# 281/281 [==============================] - 6s 21ms/step - loss: 0.0047 - val_loss: 0.0026
# Epoch 5/50
# 281/281 [==============================] - 6s 21ms/step - loss: 0.0041 - val_loss: 0.0022
# Epoch 6/50
# 281/281 [==============================] - 6s 20ms/step - loss: 0.0040 - val_loss: 0.0019
# Epoch 7/50
# 281/281 [==============================] - 6s 20ms/step - loss: 0.0039 - val_loss: 0.0016
# Epoch 8/50
# 281/281 [==============================] - 6s 20ms/step - loss: 0.0037 - val_loss: 0.0015
# Epoch 9/50
# 281/281 [==============================] - 6s 21ms/step - loss: 0.0035 - val_loss: 0.0013
# Epoch 10/50
# 281/281 [==============================] - 6s 21ms/step - loss: 0.0029 - val_loss: 0.0012
# Epoch 11/50
# 281/281 [==============================] - 6s 21ms/step - loss: 0.0032 - val_loss: 0.0011
# Epoch 12/50
# 281/281 [==============================] - 6s 21ms/step - loss: 0.0031 - val_loss: 0.0010
# Epoch 13/50
# 281/281 [==============================] - 6s 21ms/step - loss: 0.0026 - val_loss: 9.5073e-04
# Epoch 14/50
# 281/281 [==============================] - 6s 21ms/step - loss: 0.0028 - val_loss: 8.7790e-04
# Epoch 15/50
# 281/281 [==============================] - 6s 21ms/step - loss: 0.0029 - val_loss: 8.2219e-04
# Epoch 16/50
# 281/281 [==============================] - 6s 21ms/step - loss: 0.0026 - val_loss: 7.7301e-04
# Epoch 17/50
# 281/281 [==============================] - 6s 20ms/step - loss: 0.0025 - val_loss: 7.3757e-04
# Epoch 18/50
# 281/281 [==============================] - 6s 20ms/step - loss: 0.0036 - val_loss: 6.9632e-04
# Epoch 19/50
# 281/281 [==============================] - 6s 21ms/step - loss: 0.0020 - val_loss: 6.6134e-04
# Epoch 20/50
# 281/281 [==============================] - 6s 21ms/step - loss: 0.0020 - val_loss: 6.2994e-04
# Epoch 21/50
# 281/281 [==============================] - 6s 21ms/step - loss: 0.0024 - val_loss: 6.0544e-04
# Epoch 22/50
# 281/281 [==============================] - 6s 21ms/step - loss: 0.0025 - val_loss: 5.8592e-04
# Epoch 23/50
# 281/281 [==============================] - 6s 21ms/step - loss: 0.0023 - val_loss: 5.5928e-04
# Epoch 24/50
# 281/281 [==============================] - 6s 21ms/step - loss: 0.0022 - val_loss: 5.4336e-04
# Epoch 25/50
# 281/281 [==============================] - 6s 21ms/step - loss: 0.0020 - val_loss: 5.1832e-04
# Epoch 26/50
# 281/281 [==============================] - 6s 21ms/step - loss: 0.0021 - val_loss: 5.0519e-04
# Epoch 27/50
# 281/281 [==============================] - 6s 21ms/step - loss: 0.0025 - val_loss: 4.8859e-04
# Epoch 28/50
# 281/281 [==============================] - 6s 20ms/step - loss: 0.0022 - val_loss: 4.7894e-04
# Epoch 29/50
# 281/281 [==============================] - 6s 21ms/step - loss: 0.0018 - val_loss: 4.6284e-04
# Epoch 30/50
# 281/281 [==============================] - 6s 21ms/step - loss: 0.0021 - val_loss: 4.5065e-04
# Epoch 31/50
# 281/281 [==============================] - 6s 20ms/step - loss: 0.0019 - val_loss: 4.4076e-04
# Epoch 32/50
# 281/281 [==============================] - 6s 21ms/step - loss: 0.0020 - val_loss: 4.2569e-04
# Epoch 33/50
# 281/281 [==============================] - 6s 21ms/step - loss: 0.0020 - val_loss: 4.1600e-04
# Epoch 34/50
# 281/281 [==============================] - 6s 21ms/step - loss: 0.0019 - val_loss: 4.1482e-04
# Epoch 35/50
# 281/281 [==============================] - 6s 21ms/step - loss: 0.0017 - val_loss: 4.0098e-04
# Epoch 36/50
# 281/281 [==============================] - 6s 21ms/step - loss: 0.0019 - val_loss: 3.8588e-04
# Epoch 37/50
# 281/281 [==============================] - 6s 21ms/step - loss: 0.0020 - val_loss: 3.7774e-04
# Epoch 38/50
# 281/281 [==============================] - 6s 21ms/step - loss: 0.0017 - val_loss: 3.7199e-04
# Epoch 39/50
# 281/281 [==============================] - 6s 21ms/step - loss: 0.0020 - val_loss: 3.6334e-04
# Epoch 40/50
# 281/281 [==============================] - 6s 21ms/step - loss: 0.0014 - val_loss: 3.5994e-04
# Epoch 41/50
# 281/281 [==============================] - 6s 21ms/step - loss: 0.0016 - val_loss: 3.5463e-04
# Epoch 42/50
# 281/281 [==============================] - 6s 21ms/step - loss: 0.0016 - val_loss: 3.4094e-04
# Epoch 43/50
# 281/281 [==============================] - 6s 21ms/step - loss: 0.0019 - val_loss: 3.3692e-04
# Epoch 44/50
# 281/281 [==============================] - 6s 21ms/step - loss: 0.0022 - val_loss: 3.3422e-04
# Epoch 45/50
# 281/281 [==============================] - 6s 21ms/step - loss: 0.0019 - val_loss: 3.3709e-04
# Epoch 46/50
# 281/281 [==============================] - 6s 21ms/step - loss: 0.0020 - val_loss: 3.3450e-04
# Epoch 47/50
# 281/281 [==============================] - 6s 21ms/step - loss: 0.0017 - val_loss: 3.2488e-04
# Epoch 48/50
# 281/281 [==============================] - 6s 21ms/step - loss: 0.0015 - val_loss: 3.2539e-04
# Epoch 49/50
# 281/281 [==============================] - 6s 21ms/step - loss: 0.0018 - val_loss: 3.2226e-04
# Epoch 50/50
# 281/281 [==============================] - 6s 22ms/step - loss: 0.0017 - val_loss: 3.2516e-04

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'], 'r', linewidth=2, label='Training loss')
plt.plot(history.history['val_loss'], 'g', linewidth=2, label='Validation loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.legend(('Training Loss', 'Validation Loss'))
plt.show()

# %%
targets = test[target_col][window_len:]
preds = model.predict(X_test).squeeze()
mean_absolute_error(y_test, preds)
# Out:
# 18/18 [==============================] - 2s 9ms/step
# 0.011693761517676421

# %%
from sklearn.metrics import mean_squared_error

MSE = mean_squared_error(preds, y_test)
MSE
# Out:
# 0.00032516298243011235

# %%
#RMSE
import math

rmse = math.sqrt(MSE)
rmse
# Out:
# 0.018032276130042827

# %%
from sklearn.metrics import r2_score

R2 = r2_score(y_test, preds)
R2
# Out:
# -0.02862725900717278

# %%
from sklearn.metrics import mean_absolute_percentage_error

mean_absolute_percentage_error(y_test, preds)
# Out:
# 3.39433891403408

# %%
preds = test[target_col].values[:-window_len] * (preds + 1)
preds = pd.Series(index=targets.index, data=preds)
line_plot(targets, preds, 'Actual Bitcoin Prices', 'Predicted Bitcoin Prices', lw=3)

# %%
o2_preds = preds

# %%
optimizer = 'rmsprop'

model = build_hybrid_model(
    X_train, output_size=1, neurons=hybrid_neurons, dropout=dropout, loss=loss,
    optimizer=optimizer)
history = model.fit(
    X_train, y_train, validation_data=(X_test, y_test), epochs=epochs, batch_size=batch_size, verbose=1, shuffle=True)
# Out:
# Epoch 1/50
# 281/281 [==============================] - 15s 25ms/step - loss: 0.0306 - val_loss: 0.0021
# Epoch 2/50
# 281/281 [==============================] - 6s 20ms/step - loss: 0.0058 - val_loss: 8.0855e-04
# Epoch 3/50
# 281/281 [==============================] - 6s 20ms/step - loss: 0.0033 - val_loss: 0.0016
# Epoch 4/50
# 281/281 [==============================] - 6s 20ms/step - loss: 0.0021 - val_loss: 5.1034e-04
# Epoch 5/50
# 281/281 [==============================] - 6s 20ms/step - loss: 0.0013 - val_loss: 4.4348e-04
# Epoch 6/50
# 281/281 [==============================] - 6s 20ms/step - loss: 0.0013 - val_loss: 2.5956e-04
# Epoch 7/50
# 281/281 [==============================] - 6s 20ms/step - loss: 7.9252e-04 - val_loss: 4.5630e-04
# Epoch 8/50
# 281/281 [==============================] - 6s 20ms/step - loss: 6.8152e-04 - val_loss: 4.4174e-04
# Epoch 9/50
# 281/281 [==============================] - 6s 21ms/step - loss: 6.6683e-04 - val_loss: 2.2791e-04
# Epoch 10/50
# 281/281 [==============================] - 6s 21ms/step - loss: 5.1022e-04 - val_loss: 3.2039e-04
# Epoch 11/50
# 281/281 [==============================] - 6s 20ms/step - loss: 5.4554e-04 - val_loss: 6.3069e-04
# Epoch 12/50
# 281/281 [==============================] - 6s 20ms/step - loss: 5.0336e-04 - val_loss: 4.2726e-04
# Epoch 13/50
# 281/281 [==============================] - 6s 20ms/step - loss: 4.4075e-04 - val_loss: 1.8061e-04
# Epoch 14/50
# 281/281 [==============================] - 6s 20ms/step - loss: 4.2746e-04 - val_loss: 6.9028e-04
# Epoch 15/50
# 281/281 [==============================] - 6s 21ms/step - loss: 4.0384e-04 - val_loss: 2.0861e-04
# Epoch 16/50
# 281/281 [==============================] - 6s 21ms/step - loss: 4.1128e-04 - val_loss: 2.3497e-04
# Epoch 17/50
# 281/281 [==============================] - 6s 20ms/step - loss: 3.9087e-04 - val_loss: 2.9657e-04
# Epoch 18/50
# 281/281 [==============================] - 6s 21ms/step - loss: 3.7343e-04 - val_loss: 2.2846e-04
# Epoch 19/50
# 281/281 [==============================] - 6s 20ms/step - loss: 3.6890e-04 - val_loss: 2.9697e-04
# Epoch 20/50
# 281/281 [==============================] - 6s 20ms/step - loss: 3.4176e-04 - val_loss: 4.6049e-04
# Epoch 21/50
# 281/281 [==============================] - 6s 20ms/step - loss: 3.6022e-04 - val_loss: 1.9978e-04
# Epoch 22/50
# 281/281 [==============================] - 6s 20ms/step - loss: 3.3518e-04 - val_loss: 2.3156e-04
# Epoch 23/50
# 281/281 [==============================] - 6s 21ms/step - loss: 3.4886e-04 - val_loss: 2.1126e-04
# Epoch 24/50
# 281/281 [==============================] - 6s 21ms/step - loss: 3.3884e-04 - val_loss: 2.0221e-04
# Epoch 25/50
# 281/281 [==============================] - 6s 20ms/step - loss: 3.1892e-04 - val_loss: 2.1528e-04
# Epoch 26/50
# 281/281 [==============================] - 6s 20ms/step - loss: 3.1980e-04 - val_loss: 2.5986e-04
# Epoch 27/50
# 281/281 [==============================] - 6s 20ms/step - loss: 3.2822e-04 - val_loss: 1.8129e-04
# Epoch 28/50
# 281/281 [==============================] - 6s 20ms/step - loss: 3.1334e-04 - val_loss: 1.9233e-04
# Epoch 29/50
# 281/281 [==============================] - 5s 19ms/step - loss: 3.1636e-04 - val_loss: 1.8591e-04
# Epoch 30/50
# 281/281 [==============================] - 5s 19ms/step - loss: 3.0633e-04 - val_loss: 2.2516e-04
# Epoch 31/50
# 281/281 [==============================] - 5s 19ms/step - loss: 3.0282e-04 - val_loss: 1.8638e-04
# Epoch 32/50
# 281/281 [==============================] - 5s 19ms/step - loss: 2.9178e-04 - val_loss: 2.4245e-04
# Epoch 33/50
# 281/281 [==============================] - 5s 19ms/step - loss: 3.0079e-04 - val_loss: 1.7025e-04
# Epoch 34/50
# 281/281 [==============================] - 5s 19ms/step - loss: 3.1070e-04 - val_loss: 2.0384e-04
# Epoch 35/50
# 281/281 [==============================] - 5s 19ms/step - loss: 2.9336e-04 - val_loss: 2.3634e-04
# Epoch 36/50
# 281/281 [==============================] - 5s 19ms/step - loss: 2.9936e-04 - val_loss: 1.8973e-04
# Epoch 37/50
# 281/281 [==============================] - 5s 19ms/step - loss: 2.9300e-04 - val_loss: 2.6229e-04
# Epoch 38/50
# 281/281 [==============================] - 5s 19ms/step - loss: 3.0711e-04 - val_loss: 2.1780e-04
# Epoch 39/50
# 281/281 [==============================] - 5s 19ms/step - loss: 2.9263e-04 - val_loss: 2.4377e-04
# Epoch 40/50
# 281/281 [==============================] - 5s 19ms/step - loss: 2.8877e-04 - val_loss: 1.9126e-04
# Epoch 41/50
# 281/281 [==============================] - 5s 19ms/step - loss: 2.9083e-04 - val_loss: 2.3967e-04
# Epoch 42/50
# 281/281 [==============================] - 5s 19ms/step - loss: 2.9138e-04 - val_loss: 2.0327e-04
# Epoch 43/50
# 281/281 [==============================] - 5s 19ms/step - loss: 2.8590e-04 - val_loss: 1.8685e-04
# Epoch 44/50
# 281/281 [==============================] - 5s 19ms/step - loss: 2.7386e-04 - val_loss: 2.1396e-04
# Epoch 45/50
# 281/281 [==============================] - 5s 19ms/step - loss: 2.7769e-04 - val_loss: 2.2914e-04
# Epoch 46/50
# 281/281 [==============================] - 5s 19ms/step - loss: 2.8429e-04 - val_loss: 1.9849e-04
# Epoch 47/50
# 281/281 [==============================] - 5s 19ms/step - loss: 2.8638e-04 - val_loss: 2.5795e-04
# Epoch 48/50
# 281/281 [==============================] - 5s 19ms/step - loss: 2.8930e-04 - val_loss: 1.9816e-04
# Epoch 49/50
# 281/281 [==============================] - 5s 19ms/step - loss: 2.7623e-04 - val_loss: 1.9617e-04
# Epoch 50/50
# 281/281 [==============================] - 5s 19ms/step - loss: 2.6619e-04 - val_loss: 2.1014e-04

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'], 'r', linewidth=2, label='Training loss')
plt.plot(history.history['val_loss'], 'g', linewidth=2, label='Validation loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.legend(('Training Loss', 'Validation Loss'))
plt.show()

# %%
targets = test[target_col][window_len:]
preds = model.predict(X_test).squeeze()
mean_absolute_error(y_test, preds)
# Out:
# 18/18 [==============================] - 1s 9ms/step
# 0.00961524741601096

# %%
from sklearn.metrics import mean_squared_error

MSE = mean_squared_error(preds, y_test)
MSE
# Out:
# 0.00021014033288107916

# %%
#RMSE
import math

rmse = math.sqrt(MSE)
rmse
# Out:
# 0.014496217881953872

# %%
from sklearn.metrics import r2_score

R2 = r2_score(y_test, preds)
R2
# Out:
# 0.33523775368625175

# %%
from sklearn.metrics import mean_absolute_percentage_error

mean_absolute_percentage_error(y_test, preds)
# Out:
# 4.176968859298607

# %%
preds = test[target_col].values[:-window_len] * (preds + 1)
preds = pd.Series(index=targets.index, data=preds)
line_plot(targets, preds, 'Actual Bitcoin Prices', 'Predicted Bitcoin Prices', lw=3)

# %%
o3_preds = preds

# %%
optimizer = 'adagrad'

model = build_hybrid_model(
    X_train, output_size=1, neurons=hybrid_neurons, dropout=dropout, loss=loss,
    optimizer=optimizer)
history = model.fit(
    X_train, y_train, validation_data=(X_test, y_test), epochs=epochs, batch_size=batch_size, verbose=1, shuffle=True)
# Out:
# Epoch 1/50
# 281/281 [==============================] - 12s 23ms/step - loss: 0.0025 - val_loss: 5.8081e-04
# Epoch 2/50
# 281/281 [==============================] - 5s 19ms/step - loss: 0.0021 - val_loss: 4.9696e-04
# Epoch 3/50
# 281/281 [==============================] - 5s 18ms/step - loss: 0.0022 - val_loss: 5.0740e-04
# Epoch 4/50
# 281/281 [==============================] - 5s 19ms/step - loss: 0.0022 - val_loss: 4.3244e-04
# Epoch 5/50
# 281/281 [==============================] - 5s 18ms/step - loss: 0.0019 - val_loss: 4.6301e-04
# Epoch 6/50
# 281/281 [==============================] - 5s 18ms/step - loss: 0.0017 - val_loss: 4.4693e-04
# Epoch 7/50
# 281/281 [==============================] - 5s 18ms/step - loss: 0.0018 - val_loss: 4.1763e-04
# Epoch 8/50
# 281/281 [==============================] - 5s 19ms/step - loss: 0.0017 - val_loss: 3.9856e-04
# Epoch 9/50
# 281/281 [==============================] - 5s 19ms/step - loss: 0.0021 - val_loss: 4.3820e-04
# Epoch 10/50
# 281/281 [==============================] - 5s 19ms/step - loss: 0.0021 - val_loss: 4.5502e-04
# Epoch 11/50
# 281/281 [==============================] - 5s 19ms/step - loss: 0.0018 - val_loss: 3.7972e-04
# Epoch 12/50
# 281/281 [==============================] - 5s 19ms/step - loss: 0.0021 - val_loss: 3.7472e-04
# Epoch 13/50
# 281/281 [==============================] - 5s 19ms/step - loss: 0.0016 - val_loss: 5.1628e-04
# Epoch 14/50
# 281/281 [==============================] - 5s 19ms/step - loss: 0.0017 - val_loss: 3.6598e-04
# Epoch 15/50
# 281/281 [==============================] - 5s 19ms/step - loss: 0.0017 - val_loss: 3.8799e-04
# Epoch 16/50
# 281/281 [==============================] - 5s 19ms/step - loss: 0.0019 - val_loss: 3.0808e-04
# Epoch 17/50
# 281/281 [==============================] - 5s 19ms/step - loss: 0.0017 - val_loss: 3.3254e-04
# Epoch 18/50
# 281/281 [==============================] - 5s 19ms/step - loss: 0.0018 - val_loss: 2.9695e-04
# Epoch 19/50
# 281/281 [==============================] - 5s 19ms/step - loss: 0.0019 - val_loss: 3.1684e-04
# Epoch 20/50
# 281/281 [==============================] - 5s 18ms/step - loss: 0.0018 - val_loss: 3.2333e-04
# Epoch 21/50
# 281/281 [==============================] - 5s 19ms/step - loss: 0.0017 - val_loss: 3.1530e-04
# Epoch 22/50
# 281/281 [==============================] - 5s 19ms/step - loss: 0.0016 - val_loss: 3.2319e-04
# Epoch 23/50
# 281/281 [==============================] - 5s 19ms/step - loss: 0.0016 - val_loss: 3.1888e-04
# Epoch 24/50
# 281/281 [==============================] - 5s 19ms/step - loss: 0.0015 - val_loss: 3.0438e-04
# Epoch 25/50
# 281/281 [==============================] - 5s 19ms/step - loss: 0.0019 - val_loss: 2.7978e-04
# Epoch 26/50
# 281/281 [==============================] - 5s 19ms/step - loss: 0.0018 - val_loss: 3.0075e-04
# Epoch 27/50
# 281/281 [==============================] - 5s 19ms/step - loss: 0.0017 - val_loss: 2.9056e-04
# Epoch 28/50
# 281/281 [==============================] - 5s 19ms/step - loss: 0.0017 - val_loss: 3.1271e-04
# Epoch 29/50
# 281/281 [==============================] - 5s 18ms/step - loss: 0.0016 - val_loss: 3.1049e-04
# Epoch 30/50
# 281/281 [==============================] - 5s 19ms/step - loss: 0.0016 - val_loss: 2.9051e-04
# Epoch 31/50
# 281/281 [==============================] - 5s 19ms/step - loss: 0.0015 - val_loss: 2.8326e-04
# Epoch 32/50
# 281/281 [==============================] - 5s 18ms/step - loss: 0.0014 - val_loss: 2.8183e-04
# Epoch 33/50
# 281/281 [==============================] - 5s 19ms/step - loss: 0.0017 - val_loss: 2.7770e-04
# Epoch 34/50
# 281/281 [==============================] - 5s 19ms/step - loss: 0.0014 - val_loss: 2.7032e-04
# Epoch 35/50
# 281/281 [==============================] - 5s 19ms/step - loss: 0.0016 - val_loss: 2.7433e-04
# Epoch 36/50
# 281/281 [==============================] - 5s 19ms/step - loss: 0.0017 - val_loss: 3.3162e-04
# Epoch 37/50
# 281/281 [==============================] - 5s 18ms/step - loss: 0.0014 - val_loss: 3.1356e-04
# Epoch 38/50
# 281/281 [==============================] - 5s 18ms/step - loss: 0.0016 - val_loss: 2.8143e-04
# Epoch 39/50
# 281/281 [==============================] - 5s 19ms/step - loss: 0.0017 - val_loss: 2.7144e-04
# Epoch 40/50
# 281/281 [==============================] - 5s 19ms/step - loss: 0.0014 - val_loss: 2.8132e-04
# Epoch 41/50
# 281/281 [==============================] - 5s 19ms/step - loss: 0.0015 - val_loss: 2.8656e-04
# Epoch 42/50
# 281/281 [==============================] - 5s 19ms/step - loss: 0.0017 - val_loss: 2.8298e-04
# Epoch 43/50
# 281/281 [==============================] - 5s 19ms/step - loss: 0.0018 - val_loss: 2.4697e-04
# Epoch 44/50
# 281/281 [==============================] - 5s 19ms/step - loss: 0.0013 - val_loss: 2.3807e-04
# Epoch 45/50
# 281/281 [==============================] - 5s 19ms/step - loss: 0.0017 - val_loss: 2.4310e-04
# Epoch 46/50
# 281/281 [==============================] - 5s 19ms/step - loss: 0.0017 - val_loss: 3.1987e-04
# Epoch 47/50
# 281/281 [==============================] - 5s 19ms/step - loss: 0.0015 - val_loss: 2.3732e-04
# Epoch 48/50
# 281/281 [==============================] - 5s 19ms/step - loss: 0.0014 - val_loss: 2.3736e-04
# Epoch 49/50
# 281/281 [==============================] - 5s 19ms/step - loss: 0.0013 - val_loss: 2.3832e-04
# Epoch 50/50
# 281/281 [==============================] - 5s 19ms/step - loss: 0.0014 - val_loss: 2.8307e-04

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'], 'r', linewidth=2, label='Training loss')
plt.plot(history.history['val_loss'], 'g', linewidth=2, label='Validation loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.legend(('Training Loss', 'Validation Loss'))
plt.show()

# %%
targets = test[target_col][window_len:]
preds = model.predict(X_test).squeeze()
mean_absolute_error(y_test, preds)
# Out:
# 18/18 [==============================] - 1s 9ms/step
# 0.01081136202895123

# %%
from sklearn.metrics import mean_squared_error

MSE = mean_squared_error(preds, y_test)
MSE
# Out:
# 0.00028307465038869935

# %%
#RMSE
import math

rmse = math.sqrt(MSE)
rmse
# Out:
# 0.016824822447464322

# %%
from sklearn.metrics import r2_score

R2 = r2_score(y_test, preds)
R2
# Out:
# 0.10451583526631958

# %%
from sklearn.metrics import mean_absolute_percentage_error

mean_absolute_percentage_error(y_test, preds)
# Out:
# 4.205773718696958

# %%
preds = test[target_col].values[:-window_len] * (preds + 1)
preds = pd.Series(index=targets.index, data=preds)
line_plot(targets, preds, 'Actual Bitcoin Prices', 'Predicted Bitcoin Prices', lw=3)

# %%
o4_preds = preds

# %%
optimizer = 'sgd'
model = build_hybrid_model(
    X_train, output_size=1, neurons=hybrid_neurons, dropout=dropout, loss=loss,
    optimizer=optimizer)
history = model.fit(
    X_train, y_train, validation_data=(X_test, y_test), epochs=epochs, batch_size=batch_size, verbose=1, shuffle=True)
# Out:
# Epoch 1/50
# 281/281 [==============================] - 12s 23ms/step - loss: 0.0031 - val_loss: 7.0818e-04
# Epoch 2/50
# 281/281 [==============================] - 5s 18ms/step - loss: 0.0023 - val_loss: 4.8143e-04
# Epoch 3/50
# 281/281 [==============================] - 5s 18ms/step - loss: 0.0019 - val_loss: 3.4795e-04
# Epoch 4/50
# 281/281 [==============================] - 5s 18ms/step - loss: 0.0020 - val_loss: 3.0826e-04
# Epoch 5/50
# 281/281 [==============================] - 5s 18ms/step - loss: 0.0021 - val_loss: 0.0019
# Epoch 6/50
# 281/281 [==============================] - 5s 18ms/step - loss: 0.0020 - val_loss: 3.5167e-04
# Epoch 7/50
# 281/281 [==============================] - 5s 18ms/step - loss: 0.0023 - val_loss: 3.4374e-04
# Epoch 8/50
# 281/281 [==============================] - 5s 18ms/step - loss: 0.0017 - val_loss: 3.5584e-04
# Epoch 9/50
# 281/281 [==============================] - 5s 18ms/step - loss: 0.0017 - val_loss: 4.8105e-04
# Epoch 10/50
# 281/281 [==============================] - 5s 18ms/step - loss: 0.0021 - val_loss: 4.7140e-04
# Epoch 11/50
# 281/281 [==============================] - 5s 18ms/step - loss: 0.0019 - val_loss: 2.6596e-04
# Epoch 12/50
# 281/281 [==============================] - 5s 18ms/step - loss: 0.0018 - val_loss: 3.1916e-04
# Epoch 13/50
# 281/281 [==============================] - 5s 18ms/step - loss: 0.0019 - val_loss: 2.8723e-04
# Epoch 14/50
# 281/281 [==============================] - 5s 19ms/step - loss: 0.0016 - val_loss: 2.9638e-04
# Epoch 15/50
# 281/281 [==============================] - 5s 18ms/step - loss: 0.0016 - val_loss: 4.3542e-04
# Epoch 16/50
# 281/281 [==============================] - 5s 18ms/step - loss: 0.0018 - val_loss: 3.3384e-04
# Epoch 17/50
# 281/281 [==============================] - 5s 18ms/step - loss: 0.0017 - val_loss: 2.9748e-04
# Epoch 18/50
# 281/281 [==============================] - 5s 18ms/step - loss: 0.0016 - val_loss: 4.2432e-04
# Epoch 19/50
# 281/281 [==============================] - 5s 18ms/step - loss: 0.0018 - val_loss: 2.8465e-04
# Epoch 20/50
# 281/281 [==============================] - 5s 18ms/step - loss: 0.0014 - val_loss: 2.7643e-04
# Epoch 21/50
# 281/281 [==============================] - 5s 19ms/step - loss: 0.0012 - val_loss: 2.4927e-04
# Epoch 22/50
# 281/281 [==============================] - 5s 19ms/step - loss: 0.0012 - val_loss: 2.2071e-04
# Epoch 23/50
# 281/281 [==============================] - 5s 19ms/step - loss: 0.0013 - val_loss: 3.6027e-04
# Epoch 24/50
# 281/281 [==============================] - 5s 18ms/step - loss: 0.0014 - val_loss: 3.0616e-04
# Epoch 25/50
# 281/281 [==============================] - 5s 19ms/step - loss: 0.0014 - val_loss: 4.1709e-04
# Epoch 26/50
# 281/281 [==============================] - 5s 19ms/step - loss: 0.0012 - val_loss: 2.9918e-04
# Epoch 27/50
# 281/281 [==============================] - 5s 19ms/step - loss: 0.0013 - val_loss: 3.0202e-04
# Epoch 28/50
# 281/281 [==============================] - 5s 19ms/step - loss: 0.0014 - val_loss: 2.3532e-04
# Epoch 29/50
# 281/281 [==============================] - 5s 18ms/step - loss: 0.0013 - val_loss: 2.9924e-04
# Epoch 30/50
# 281/281 [==============================] - 5s 18ms/step - loss: 0.0011 - val_loss: 2.0458e-04
# Epoch 31/50
# 281/281 [==============================] - 5s 18ms/step - loss: 0.0011 - val_loss: 3.1406e-04
# Epoch 32/50
# 281/281 [==============================] - 5s 18ms/step - loss: 0.0012 - val_loss: 2.5314e-04
# Epoch 33/50
# 281/281 [==============================] - 5s 18ms/step - loss: 0.0012 - val_loss: 2.3773e-04
# Epoch 34/50
# 281/281 [==============================] - 5s 18ms/step - loss: 0.0013 - val_loss: 3.5454e-04
# Epoch 35/50
# 281/281 [==============================] - 5s 19ms/step - loss: 0.0011 - val_loss: 2.7867e-04
# Epoch 36/50
# 281/281 [==============================] - 5s 18ms/step - loss: 0.0012 - val_loss: 2.5648e-04
# Epoch 37/50
# 281/281 [==============================] - 5s 18ms/step - loss: 0.0011 - val_loss: 2.6310e-04
# Epoch 38/50
# 281/281 [==============================] - 5s 18ms/step - loss: 0.0011 - val_loss: 2.3007e-04
# Epoch 39/50
# 281/281 [==============================] - 5s 18ms/step - loss: 0.0011 - val_loss: 2.2068e-04
# Epoch 40/50
# 281/281 [==============================] - 5s 18ms/step - loss: 9.3446e-04 - val_loss: 2.0217e-04
# Epoch 41/50
# 281/281 [==============================] - 5s 18ms/step - loss: 0.0012 - val_loss: 2.1023e-04
# Epoch 42/50
# 281/281 [==============================] - 5s 19ms/step - loss: 0.0011 - val_loss: 2.3197e-04
# Epoch 43/50
# 281/281 [==============================] - 5s 19ms/step - loss: 0.0011 - val_loss: 2.2639e-04
# Epoch 44/50
# 281/281 [==============================] - 5s 19ms/step - loss: 9.1819e-04 - val_loss: 2.1336e-04
# Epoch 45/50
# 281/281 [==============================] - 5s 19ms/step - loss: 0.0010 - val_loss: 2.9765e-04
# Epoch 46/50
# 281/281 [==============================] - 5s 18ms/step - loss: 9.8506e-04 - val_loss: 2.4421e-04
# Epoch 47/50
# 281/281 [==============================] - 5s 18ms/step - loss: 9.7502e-04 - val_loss: 2.6852e-04
# Epoch 48/50
# 281/281 [==============================] - 5s 18ms/step - loss: 0.0011 - val_loss: 2.4067e-04
# Epoch 49/50
# 281/281 [==============================] - 5s 18ms/step - loss: 0.0013 - val_loss: 3.1537e-04
# Epoch 50/50
# 281/281 [==============================] - 5s 18ms/step - loss: 0.0011 - val_loss: 2.6080e-04

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'], 'r', linewidth=2, label='Training loss')
plt.plot(history.history['val_loss'], 'g', linewidth=2, label='Validation loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.legend(('Training Loss', 'Validation Loss'))
plt.show()

# %%
targets = test[target_col][window_len:]
preds = model.predict(X_test).squeeze()
mean_absolute_error(y_test, preds)
# Out:
# 18/18 [==============================] - 2s 9ms/step
# 0.009925401252218111

# %%
from sklearn.metrics import mean_squared_error

MSE = mean_squared_error(preds, y_test)
MSE
# Out:
# 0.00026080010523535233

# %%
#RMSE
import math

rmse = math.sqrt(MSE)
rmse
# Out:
# 0.016149306648749733

# %%
from sklearn.metrics import r2_score

R2 = r2_score(y_test, preds)
R2
# Out:
# 0.17497958902907584

# %%
from sklearn.metrics import mean_absolute_percentage_error

mean_absolute_percentage_error(y_test, preds)
# Out:
# 3.5147982263031046

# %%
preds = test[target_col].values[:-window_len] * (preds + 1)
preds = pd.Series(index=targets.index, data=preds)
line_plot(targets, preds, 'Actual Bitcoin Prices', 'Predicted Bitcoin Prices', lw=3)

# %%
o5_preds = preds

# %%
def line_plot2(line1, line2, line3, line4, line5, line6, label1=None, label2=None, label3=None, label4=None,
               label5=None, label6=None, title='', lw=2):
    fig, ax = plt.subplots(1, figsize=(15, 6))
    ax.plot(line1, label=label1, linewidth=lw)
    ax.plot(line2, label=label2, linewidth=lw)
    ax.plot(line3, label=label3, linewidth=lw)
    ax.plot(line4, label=label4, linewidth=lw)
    ax.plot(line5, label=label5, linewidth=lw)
    ax.plot(line6, label=label6, linewidth=lw)
    ax.set_ylabel('price [BTC]', fontsize=18)
    ax.set_xlabel('Date', fontsize=18)
    ax.tick_params(labelsize=11)
    ax.set_title(title, fontsize=16)
    ax.legend(loc='best', fontsize=11)

# %%
line_plot2(targets, o1_preds, o2_preds, o3_preds, o4_preds, o5_preds, 'Actual Bitcoin Prices',
           'Adam', 'AdaDelta', 'RMSprop', 'AdaGrad','SGD', lw=2)
